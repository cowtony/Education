# %% [markdown]
# ## Mounting Google Drive locally

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##Import Package
# - ML: tensorflow, keras
# - Visualization: matplotlib.pyplot
# - numpy -> loadtxt

# %%
from numpy import loadtxt
import tensorflow as tf
import keras
import matplotlib.pyplot as plt
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.

# %% [markdown]
# ##Load Data from Google Drive
# [Numpy loadtxt](https://docs.scipy.org/doc/numpy/reference/generated/numpy.loadtxt.html)
#
# Diabetes Data in Classroom folder

# %%
dataset = loadtxt('/content/drive/My Drive/Classroom/Python AI Application Level I 2020 Winter @ mYe/heart_disease_data_raw.csv', delimiter = ',')

# %% [markdown]
# #Understanding data
# [Heart Disease Data @ Kaggle](https://www.kaggle.com/ronitf/heart-disease-uci)
#
# Input:
# > 1. age
# > 2. sex
# > 3. chest pain type (4 values)
# > 4. resting blood pressure
# > 5. serum cholestoral in mg/dl
# > 6. fasting blood sugar > 120 mg/dl
# > 7. resting electrocardiographic results (values 0,1,2)
# > 8. maximum heart rate achieved
# > 9. exercise induced angina
# > 10. oldpeak = ST depression induced by exercise relative to rest
# > 11. the slope of the peak exercise ST segment
# > 12. number of major vessels (0-3) colored by flourosopy
# > 13. thal: 3 = normal; 6 = fixed defect; 7 = reversable defec
#
# Output:
# > 0 = disease,
# > 1 = no disease

# %% [markdown]
# #Split Data
#  - Input: first 13 index, from index 0 - 12
#  - Output: last 1 index, index 13

# %%
x = dataset[:, 0:13]
y = dataset[:,13]

# %% [markdown]
# Check data splitting

# %%
x[0]
# Out:
# array([ 63. ,   1. ,   3. , 145. , 233. ,   1. ,   0. , 150. ,   0. ,
#          2.3,   0. ,   0. ,   1. ])

# %%
y[0]
# Out:
# 1.0

# %% [markdown]
# #Build Model
# How do we know number of layer and type of layers?
# - Experimental, trail & error to find the best model architecture
#
# Here is an example
# - Input Dimension: The model expects rows of data with 13 variables (the input_dim=13 argument)
# - Hidden layer (1st): 64 nodes and uses the tanh activation function. Need to specify your input dimension here
# - Hidden layer (2nd): 64 nodes and uses the tanh activation function.
# - Hidden layer (3rd): 32 nodes and use tanh activation function
# - Output layer (last): 1 node and uses the sigmoid activation function.

# %%
def create_model():
  model = tf.keras.Sequential()
  model.add(tf.keras.layers.Dense(64, input_dim = 13, activation = 'tanh'))
  model.add(tf.keras.layers.Dense(64, activation = 'tanh'))
  #sigmoid
  model.add(tf.keras.layers.Dense(1, activation = 'sigmoid'))


  return model

# %% [markdown]
# #Compile Model
# [Keras Model Compile](https://keras.io/models/model/)
#
# use model.summary()
#
#
# Compiling model uses backend lib like Theano or Tensorflow.
# - Loss Function: use to evaluate a set of weight
#
#   [How to choose loss function](https://machinelearningmastery.com/how-to-choose-loss-functions-when-training-deep-learning-neural-networks/)
# - Optimizer: used to sesarch through different weights for the network and any optional metrics we would like to collect and report during training
#
#   [Adam Optimization Algo](https://machinelearningmastery.com/adam-optimization-algorithm-for-deep-learning/)

# %%
model = create_model()

model.summary()

model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                896
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 5,121
# Trainable params: 5,121
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %% [markdown]
# #Train (fit) Model
# [Keras Model.fit()](https://keras.rstudio.com/reference/fit.html)
#
# - Epoch: 1 pass through all rows in training data set
# - Batch: one or more samples considered by the model within an epoch before weights are updated
# - Verbose: Verbosity mode (0 = silent, 1 = progress bar, 2 = one line per epoch).
# - Validation_split:
# Float between 0 and 1. Fraction of the training data to be used as validation data.

# %%
 history = model.fit(x,y, epochs = 150, batch_size = 15, validation_split = 0.2)
# Out:
# Train on 242 samples, validate on 61 samples
# Epoch 1/150
# 242/242 [==============================] - 0s 1ms/sample - loss: 0.6288 - acc: 0.6570 - val_loss: 0.9507 - val_acc: 0.4098
# Epoch 2/150
# 242/242 [==============================] - 0s 135us/sample - loss: 0.5805 - acc: 0.7066 - val_loss: 1.1424 - val_acc: 0.2459
# Epoch 3/150
# 242/242 [==============================] - 0s 170us/sample - loss: 0.5593 - acc: 0.7397 - val_loss: 0.9454 - val_acc: 0.5082
# Epoch 4/150
# 242/242 [==============================] - 0s 141us/sample - loss: 0.5687 - acc: 0.6736 - val_loss: 0.9941 - val_acc: 0.3607
# Epoch 5/150
# 242/242 [==============================] - 0s 152us/sample - loss: 0.5617 - acc: 0.7314 - val_loss: 1.3166 - val_acc: 0.1148
# Epoch 6/150
# 242/242 [==============================] - 0s 135us/sample - loss: 0.5615 - acc: 0.6777 - val_loss: 1.0897 - val_acc: 0.2623
# Epoch 7/150
# 242/242 [==============================] - 0s 140us/sample - loss: 0.5477 - acc: 0.7149 - val_loss: 0.9302 - val_acc: 0.4590
# Epoch 8/150
# 242/242 [==============================] - 0s 146us/sample - loss: 0.5584 - acc: 0.6860 - val_loss: 1.1165 - val_acc: 0.2295
# Epoch 9/150
# 242/242 [==============================] - 0s 192us/sample - loss: 0.5446 - acc: 0.7107 - val_loss: 0.8468 - val_acc: 0.5082
# Epoch 10/150
# 242/242 [==============================] - 0s 166us/sample - loss: 0.5576 - acc: 0.7107 - val_loss: 0.8173 - val_acc: 0.5246
# Epoch 11/150
# 242/242 [==============================] - 0s 134us/sample - loss: 0.5859 - acc: 0.6653 - val_loss: 1.3733 - val_acc: 0.0820
# Epoch 12/150
# 242/242 [==============================] - 0s 135us/sample - loss: 0.5750 - acc: 0.7190 - val_loss: 0.7647 - val_acc: 0.5410
# Epoch 13/150
# 242/242 [==============================] - 0s 180us/sample - loss: 0.5520 - acc: 0.6942 - val_loss: 1.1830 - val_acc: 0.2131
# Epoch 14/150
# 242/242 [==============================] - 0s 151us/sample - loss: 0.5526 - acc: 0.7025 - val_loss: 1.1302 - val_acc: 0.2623
# Epoch 15/150
# 242/242 [==============================] - 0s 136us/sample - loss: 0.5607 - acc: 0.7025 - val_loss: 0.9234 - val_acc: 0.3934
# Epoch 16/150
# 242/242 [==============================] - 0s 145us/sample - loss: 0.5413 - acc: 0.7397 - val_loss: 1.0594 - val_acc: 0.2951
# Epoch 17/150
# 242/242 [==============================] - 0s 134us/sample - loss: 0.5418 - acc: 0.7190 - val_loss: 0.8609 - val_acc: 0.4262
# Epoch 18/150
# 242/242 [==============================] - 0s 138us/sample - loss: 0.5499 - acc: 0.7479 - val_loss: 1.3031 - val_acc: 0.1311
# Epoch 19/150
# 242/242 [==============================] - 0s 135us/sample - loss: 0.5695 - acc: 0.7397 - val_loss: 0.8327 - val_acc: 0.4590
# Epoch 20/150
# 242/242 [==============================] - 0s 150us/sample - loss: 0.5432 - acc: 0.7355 - val_loss: 1.0202 - val_acc: 0.3279
# Epoch 21/150
# 242/242 [==============================] - 0s 132us/sample - loss: 0.5370 - acc: 0.7273 - val_loss: 0.9277 - val_acc: 0.4262
# Epoch 22/150
# 242/242 [==============================] - 0s 149us/sample - loss: 0.5401 - acc: 0.7273 - val_loss: 0.8671 - val_acc: 0.4426
# Epoch 23/150
# 242/242 [==============================] - 0s 147us/sample - loss: 0.5336 - acc: 0.7438 - val_loss: 1.1208 - val_acc: 0.2787
# Epoch 24/150
# 242/242 [==============================] - 0s 138us/sample - loss: 0.5298 - acc: 0.7231 - val_loss: 0.8115 - val_acc: 0.5246
# Epoch 25/150
# 242/242 [==============================] - 0s 139us/sample - loss: 0.5281 - acc: 0.7355 - val_loss: 0.8921 - val_acc: 0.4426
# Epoch 26/150
# 242/242 [==============================] - 0s 144us/sample - loss: 0.5269 - acc: 0.7397 - val_loss: 1.0924 - val_acc: 0.3443
# Epoch 27/150
# 242/242 [==============================] - 0s 135us/sample - loss: 0.5165 - acc: 0.7397 - val_loss: 0.9066 - val_acc: 0.4426
# Epoch 28/150
# 242/242 [==============================] - 0s 138us/sample - loss: 0.5200 - acc: 0.7397 - val_loss: 1.1239 - val_acc: 0.3443
# Epoch 29/150
# 242/242 [==============================] - 0s 146us/sample - loss: 0.5219 - acc: 0.7521 - val_loss: 0.7661 - val_acc: 0.5246
# Epoch 30/150
# 242/242 [==============================] - 0s 147us/sample - loss: 0.5128 - acc: 0.7521 - val_loss: 0.8492 - val_acc: 0.4918
# Epoch 31/150
# 242/242 [==============================] - 0s 164us/sample - loss: 0.5014 - acc: 0.7438 - val_loss: 0.9053 - val_acc: 0.4590
# Epoch 32/150
# 242/242 [==============================] - 0s 160us/sample - loss: 0.4910 - acc: 0.7562 - val_loss: 0.9029 - val_acc: 0.4754
# Epoch 33/150
# 242/242 [==============================] - 0s 138us/sample - loss: 0.4943 - acc: 0.7603 - val_loss: 0.9966 - val_acc: 0.3443
# Epoch 34/150
# 242/242 [==============================] - 0s 151us/sample - loss: 0.5043 - acc: 0.7479 - val_loss: 0.9804 - val_acc: 0.4098
# Epoch 35/150
# 242/242 [==============================] - 0s 129us/sample - loss: 0.5410 - acc: 0.7314 - val_loss: 0.6070 - val_acc: 0.6721
# Epoch 36/150
# 242/242 [==============================] - 0s 137us/sample - loss: 0.5192 - acc: 0.7397 - val_loss: 0.9810 - val_acc: 0.4262
# Epoch 37/150
# 242/242 [==============================] - 0s 148us/sample - loss: 0.4938 - acc: 0.7479 - val_loss: 1.1223 - val_acc: 0.3934
# Epoch 38/150
# 242/242 [==============================] - 0s 170us/sample - loss: 0.4878 - acc: 0.7521 - val_loss: 0.8547 - val_acc: 0.4754
# Epoch 39/150
# 242/242 [==============================] - 0s 139us/sample - loss: 0.4849 - acc: 0.7727 - val_loss: 0.8919 - val_acc: 0.4590
# Epoch 40/150
# 242/242 [==============================] - 0s 144us/sample - loss: 0.4898 - acc: 0.7727 - val_loss: 1.1638 - val_acc: 0.2951
# Epoch 41/150
# 242/242 [==============================] - 0s 148us/sample - loss: 0.5040 - acc: 0.7603 - val_loss: 0.9104 - val_acc: 0.4754
# Epoch 42/150
# 242/242 [==============================] - 0s 146us/sample - loss: 0.5085 - acc: 0.7397 - val_loss: 0.8065 - val_acc: 0.4590
# Epoch 43/150
# 242/242 [==============================] - 0s 139us/sample - loss: 0.4848 - acc: 0.7769 - val_loss: 0.9347 - val_acc: 0.4262
# Epoch 44/150
# 242/242 [==============================] - 0s 163us/sample - loss: 0.4839 - acc: 0.7438 - val_loss: 1.0221 - val_acc: 0.3607
# Epoch 45/150
# 242/242 [==============================] - 0s 149us/sample - loss: 0.4702 - acc: 0.7686 - val_loss: 0.7610 - val_acc: 0.5574
# Epoch 46/150
# 242/242 [==============================] - 0s 147us/sample - loss: 0.4864 - acc: 0.7603 - val_loss: 0.7642 - val_acc: 0.5246
# Epoch 47/150
# 242/242 [==============================] - 0s 148us/sample - loss: 0.4601 - acc: 0.7893 - val_loss: 1.1444 - val_acc: 0.3607
# Epoch 48/150
# 242/242 [==============================] - 0s 136us/sample - loss: 0.4978 - acc: 0.7438 - val_loss: 0.7427 - val_acc: 0.5574
# Epoch 49/150
# 242/242 [==============================] - 0s 144us/sample - loss: 0.4839 - acc: 0.7521 - val_loss: 1.1609 - val_acc: 0.3443
# Epoch 50/150
# 242/242 [==============================] - 0s 170us/sample - loss: 0.4805 - acc: 0.7562 - val_loss: 0.8525 - val_acc: 0.5738
# Epoch 51/150
# 242/242 [==============================] - 0s 149us/sample - loss: 0.4821 - acc: 0.7769 - val_loss: 0.9036 - val_acc: 0.5410
# Epoch 52/150
# 242/242 [==============================] - 0s 138us/sample - loss: 0.4644 - acc: 0.7727 - val_loss: 1.1558 - val_acc: 0.3443
# Epoch 53/150
# 242/242 [==============================] - 0s 135us/sample - loss: 0.4782 - acc: 0.7769 - val_loss: 0.6524 - val_acc: 0.6230
# Epoch 54/150
# 242/242 [==============================] - 0s 135us/sample - loss: 0.4667 - acc: 0.7727 - val_loss: 0.7885 - val_acc: 0.5574
# Epoch 55/150
# 242/242 [==============================] - 0s 143us/sample - loss: 0.4516 - acc: 0.7975 - val_loss: 0.8632 - val_acc: 0.5082
# Epoch 56/150
# 242/242 [==============================] - 0s 150us/sample - loss: 0.4434 - acc: 0.8017 - val_loss: 1.0786 - val_acc: 0.3607
# Epoch 57/150
# 242/242 [==============================] - 0s 160us/sample - loss: 0.4409 - acc: 0.8099 - val_loss: 1.1992 - val_acc: 0.3279
# Epoch 58/150
# 242/242 [==============================] - 0s 182us/sample - loss: 0.4582 - acc: 0.8223 - val_loss: 1.0335 - val_acc: 0.4262
# Epoch 59/150
# 242/242 [==============================] - 0s 160us/sample - loss: 0.4415 - acc: 0.7893 - val_loss: 1.1611 - val_acc: 0.3607
# Epoch 60/150
# 242/242 [==============================] - 0s 156us/sample - loss: 0.4361 - acc: 0.8058 - val_loss: 0.9371 - val_acc: 0.4918
# Epoch 61/150
# 242/242 [==============================] - 0s 144us/sample - loss: 0.4220 - acc: 0.8099 - val_loss: 0.5707 - val_acc: 0.7869
# Epoch 62/150
# 242/242 [==============================] - 0s 138us/sample - loss: 0.4024 - acc: 0.8347 - val_loss: 0.7593 - val_acc: 0.5902
# Epoch 63/150
# 242/242 [==============================] - 0s 136us/sample - loss: 0.3992 - acc: 0.8388 - val_loss: 1.0473 - val_acc: 0.4262
# Epoch 64/150
# 242/242 [==============================] - 0s 136us/sample - loss: 0.4468 - acc: 0.7975 - val_loss: 1.2564 - val_acc: 0.4262
# Epoch 65/150
# 242/242 [==============================] - 0s 172us/sample - loss: 0.3999 - acc: 0.8430 - val_loss: 1.2079 - val_acc: 0.3934
# Epoch 66/150
# 242/242 [==============================] - 0s 148us/sample - loss: 0.4258 - acc: 0.8264 - val_loss: 0.8865 - val_acc: 0.5574
# Epoch 67/150
# 242/242 [==============================] - 0s 155us/sample - loss: 0.3803 - acc: 0.8430 - val_loss: 0.8430 - val_acc: 0.5738
# Epoch 68/150
# 242/242 [==============================] - 0s 137us/sample - loss: 0.3831 - acc: 0.8595 - val_loss: 0.7850 - val_acc: 0.6066
# Epoch 69/150
# 242/242 [==============================] - 0s 142us/sample - loss: 0.3743 - acc: 0.8595 - val_loss: 1.1101 - val_acc: 0.4098
# Epoch 70/150
# 242/242 [==============================] - 0s 154us/sample - loss: 0.3722 - acc: 0.8595 - val_loss: 0.8804 - val_acc: 0.5574
# Epoch 71/150
# 242/242 [==============================] - 0s 161us/sample - loss: 0.3863 - acc: 0.8678 - val_loss: 1.2623 - val_acc: 0.4098
# Epoch 72/150
# 242/242 [==============================] - 0s 154us/sample - loss: 0.3576 - acc: 0.8636 - val_loss: 0.6392 - val_acc: 0.6721
# Epoch 73/150
# 242/242 [==============================] - 0s 154us/sample - loss: 0.3761 - acc: 0.8347 - val_loss: 0.9356 - val_acc: 0.5902
# Epoch 74/150
# 242/242 [==============================] - 0s 135us/sample - loss: 0.3794 - acc: 0.8430 - val_loss: 0.6863 - val_acc: 0.6557
# Epoch 75/150
# 242/242 [==============================] - 0s 145us/sample - loss: 0.3614 - acc: 0.8595 - val_loss: 0.9882 - val_acc: 0.5574
# Epoch 76/150
# 242/242 [==============================] - 0s 140us/sample - loss: 0.3570 - acc: 0.8512 - val_loss: 0.8685 - val_acc: 0.6066
# Epoch 77/150
# 242/242 [==============================] - 0s 142us/sample - loss: 0.3667 - acc: 0.8636 - val_loss: 1.1879 - val_acc: 0.5574
# Epoch 78/150
# 242/242 [==============================] - 0s 145us/sample - loss: 0.3860 - acc: 0.8264 - val_loss: 1.2792 - val_acc: 0.4426
# Epoch 79/150
# 242/242 [==============================] - 0s 138us/sample - loss: 0.3930 - acc: 0.8140 - val_loss: 0.6125 - val_acc: 0.6721
# Epoch 80/150
# 242/242 [==============================] - 0s 140us/sample - loss: 0.3630 - acc: 0.8760 - val_loss: 0.6366 - val_acc: 0.6885
# Epoch 81/150
# 242/242 [==============================] - 0s 152us/sample - loss: 0.3753 - acc: 0.8554 - val_loss: 0.5829 - val_acc: 0.6885
# Epoch 82/150
# 242/242 [==============================] - 0s 163us/sample - loss: 0.3811 - acc: 0.8347 - val_loss: 0.8163 - val_acc: 0.6066
# Epoch 83/150
# 242/242 [==============================] - 0s 157us/sample - loss: 0.3393 - acc: 0.8512 - val_loss: 1.4098 - val_acc: 0.4262
# Epoch 84/150
# 242/242 [==============================] - 0s 145us/sample - loss: 0.4137 - acc: 0.8140 - val_loss: 1.2907 - val_acc: 0.4590
# Epoch 85/150
# 242/242 [==============================] - 0s 144us/sample - loss: 0.3571 - acc: 0.8554 - val_loss: 1.1527 - val_acc: 0.5574
# Epoch 86/150
# 242/242 [==============================] - 0s 150us/sample - loss: 0.3553 - acc: 0.8595 - val_loss: 1.0521 - val_acc: 0.5902
# Epoch 87/150
# 242/242 [==============================] - 0s 141us/sample - loss: 0.3784 - acc: 0.8347 - val_loss: 1.3238 - val_acc: 0.4262
# Epoch 88/150
# 242/242 [==============================] - 0s 158us/sample - loss: 0.3783 - acc: 0.8471 - val_loss: 1.2081 - val_acc: 0.4262
# Epoch 89/150
# 242/242 [==============================] - 0s 153us/sample - loss: 0.3387 - acc: 0.8802 - val_loss: 0.7568 - val_acc: 0.6230
# Epoch 90/150
# 242/242 [==============================] - 0s 147us/sample - loss: 0.3263 - acc: 0.8719 - val_loss: 0.8587 - val_acc: 0.5902
# Epoch 91/150
# 242/242 [==============================] - 0s 142us/sample - loss: 0.3214 - acc: 0.8760 - val_loss: 1.1788 - val_acc: 0.5738
# Epoch 92/150
# 242/242 [==============================] - 0s 130us/sample - loss: 0.3378 - acc: 0.8636 - val_loss: 0.7009 - val_acc: 0.6557
# Epoch 93/150
# 242/242 [==============================] - 0s 157us/sample - loss: 0.3354 - acc: 0.8512 - val_loss: 0.9285 - val_acc: 0.5902
# Epoch 94/150
# 242/242 [==============================] - 0s 141us/sample - loss: 0.3406 - acc: 0.8678 - val_loss: 1.1078 - val_acc: 0.5738
# Epoch 95/150
# 242/242 [==============================] - 0s 162us/sample - loss: 0.3256 - acc: 0.8595 - val_loss: 0.8736 - val_acc: 0.6066
# Epoch 96/150
# 242/242 [==============================] - 0s 144us/sample - loss: 0.3236 - acc: 0.8636 - val_loss: 0.7883 - val_acc: 0.6393
# Epoch 97/150
# 242/242 [==============================] - 0s 149us/sample - loss: 0.3552 - acc: 0.8471 - val_loss: 0.5644 - val_acc: 0.7049
# Epoch 98/150
# 242/242 [==============================] - 0s 158us/sample - loss: 0.3872 - acc: 0.8306 - val_loss: 0.9229 - val_acc: 0.5574
# Epoch 99/150
# 242/242 [==============================] - 0s 149us/sample - loss: 0.3467 - acc: 0.8512 - val_loss: 0.7482 - val_acc: 0.6557
# Epoch 100/150
# 242/242 [==============================] - 0s 144us/sample - loss: 0.3894 - acc: 0.8264 - val_loss: 0.9294 - val_acc: 0.5902
# Epoch 101/150
# 242/242 [==============================] - 0s 150us/sample - loss: 0.3477 - acc: 0.8678 - val_loss: 0.8109 - val_acc: 0.6066
# Epoch 102/150
# 242/242 [==============================] - 0s 147us/sample - loss: 0.3329 - acc: 0.8884 - val_loss: 0.8210 - val_acc: 0.6721
# Epoch 103/150
# 242/242 [==============================] - 0s 145us/sample - loss: 0.3291 - acc: 0.8926 - val_loss: 0.6853 - val_acc: 0.6393
# Epoch 104/150
# 242/242 [==============================] - 0s 153us/sample - loss: 0.3541 - acc: 0.8719 - val_loss: 1.1320 - val_acc: 0.5738
# Epoch 105/150
# 242/242 [==============================] - 0s 141us/sample - loss: 0.3193 - acc: 0.8595 - val_loss: 1.6422 - val_acc: 0.3607
# Epoch 106/150
# 242/242 [==============================] - 0s 143us/sample - loss: 0.4121 - acc: 0.8223 - val_loss: 1.2226 - val_acc: 0.5246
# Epoch 107/150
# 242/242 [==============================] - 0s 146us/sample - loss: 0.3594 - acc: 0.8388 - val_loss: 0.5522 - val_acc: 0.7049
# Epoch 108/150
# 242/242 [==============================] - 0s 152us/sample - loss: 0.3117 - acc: 0.8719 - val_loss: 0.7646 - val_acc: 0.6393
# Epoch 109/150
# 242/242 [==============================] - 0s 155us/sample - loss: 0.2985 - acc: 0.8884 - val_loss: 1.0124 - val_acc: 0.5902
# Epoch 110/150
# 242/242 [==============================] - 0s 166us/sample - loss: 0.2996 - acc: 0.8884 - val_loss: 0.7416 - val_acc: 0.6393
# Epoch 111/150
# 242/242 [==============================] - 0s 157us/sample - loss: 0.3259 - acc: 0.8719 - val_loss: 1.2704 - val_acc: 0.4590
# Epoch 112/150
# 242/242 [==============================] - 0s 144us/sample - loss: 0.3546 - acc: 0.8471 - val_loss: 1.2479 - val_acc: 0.5574
# Epoch 113/150
# 242/242 [==============================] - 0s 150us/sample - loss: 0.3270 - acc: 0.8595 - val_loss: 0.3464 - val_acc: 0.8033
# Epoch 114/150
# 242/242 [==============================] - 0s 151us/sample - loss: 0.3699 - acc: 0.8554 - val_loss: 0.9927 - val_acc: 0.6066
# Epoch 115/150
# 242/242 [==============================] - 0s 144us/sample - loss: 0.3081 - acc: 0.8843 - val_loss: 0.7541 - val_acc: 0.6557
# Epoch 116/150
# 242/242 [==============================] - 0s 153us/sample - loss: 0.3007 - acc: 0.8967 - val_loss: 1.0403 - val_acc: 0.5902
# Epoch 117/150
# 242/242 [==============================] - 0s 171us/sample - loss: 0.2975 - acc: 0.8884 - val_loss: 0.8126 - val_acc: 0.6393
# Epoch 118/150
# 242/242 [==============================] - 0s 137us/sample - loss: 0.2895 - acc: 0.8926 - val_loss: 0.9365 - val_acc: 0.6066
# Epoch 119/150
# 242/242 [==============================] - 0s 136us/sample - loss: 0.2921 - acc: 0.8967 - val_loss: 0.6557 - val_acc: 0.7049
# Epoch 120/150
# 242/242 [==============================] - 0s 163us/sample - loss: 0.3102 - acc: 0.8843 - val_loss: 0.9771 - val_acc: 0.5738
# Epoch 121/150
# 242/242 [==============================] - 0s 144us/sample - loss: 0.3016 - acc: 0.8967 - val_loss: 0.9400 - val_acc: 0.6393
# Epoch 122/150
# 242/242 [==============================] - 0s 158us/sample - loss: 0.2824 - acc: 0.9008 - val_loss: 0.5766 - val_acc: 0.7213
# Epoch 123/150
# 242/242 [==============================] - 0s 156us/sample - loss: 0.2999 - acc: 0.8843 - val_loss: 0.9471 - val_acc: 0.6066
# Epoch 124/150
# 242/242 [==============================] - 0s 167us/sample - loss: 0.3089 - acc: 0.8802 - val_loss: 0.9770 - val_acc: 0.6230
# Epoch 125/150
# 242/242 [==============================] - 0s 157us/sample - loss: 0.2988 - acc: 0.8719 - val_loss: 1.4280 - val_acc: 0.4754
# Epoch 126/150
# 242/242 [==============================] - 0s 140us/sample - loss: 0.3064 - acc: 0.8802 - val_loss: 1.0275 - val_acc: 0.6066
# Epoch 127/150
# 242/242 [==============================] - 0s 143us/sample - loss: 0.3004 - acc: 0.8884 - val_loss: 0.9645 - val_acc: 0.6230
# Epoch 128/150
# 242/242 [==============================] - 0s 168us/sample - loss: 0.2904 - acc: 0.8884 - val_loss: 1.1419 - val_acc: 0.5902
# Epoch 129/150
# 242/242 [==============================] - 0s 156us/sample - loss: 0.2904 - acc: 0.8967 - val_loss: 0.7526 - val_acc: 0.6557
# Epoch 130/150
# 242/242 [==============================] - 0s 147us/sample - loss: 0.2650 - acc: 0.9008 - val_loss: 1.4588 - val_acc: 0.5082
# Epoch 131/150
# 242/242 [==============================] - 0s 140us/sample - loss: 0.3119 - acc: 0.8967 - val_loss: 1.0401 - val_acc: 0.6393
# Epoch 132/150
# 242/242 [==============================] - 0s 147us/sample - loss: 0.2875 - acc: 0.8884 - val_loss: 1.3389 - val_acc: 0.5738
# Epoch 133/150
# 242/242 [==============================] - 0s 145us/sample - loss: 0.3124 - acc: 0.8843 - val_loss: 1.2039 - val_acc: 0.5574
# Epoch 134/150
# 242/242 [==============================] - 0s 155us/sample - loss: 0.3029 - acc: 0.8802 - val_loss: 0.6599 - val_acc: 0.6885
# Epoch 135/150
# 242/242 [==============================] - 0s 137us/sample - loss: 0.3400 - acc: 0.8595 - val_loss: 1.0039 - val_acc: 0.6557
# Epoch 136/150
# 242/242 [==============================] - 0s 181us/sample - loss: 0.3519 - acc: 0.8636 - val_loss: 0.8933 - val_acc: 0.6721
# Epoch 137/150
# 242/242 [==============================] - 0s 140us/sample - loss: 0.3092 - acc: 0.8884 - val_loss: 1.2345 - val_acc: 0.5738
# Epoch 138/150
# 242/242 [==============================] - 0s 146us/sample - loss: 0.3058 - acc: 0.8884 - val_loss: 1.0131 - val_acc: 0.6066
# Epoch 139/150
# 242/242 [==============================] - 0s 152us/sample - loss: 0.3081 - acc: 0.8884 - val_loss: 1.1909 - val_acc: 0.5738
# Epoch 140/150
# 242/242 [==============================] - 0s 144us/sample - loss: 0.2894 - acc: 0.8802 - val_loss: 0.7111 - val_acc: 0.6885
# Epoch 141/150
# 242/242 [==============================] - 0s 156us/sample - loss: 0.2798 - acc: 0.8802 - val_loss: 1.3650 - val_acc: 0.5246
# Epoch 142/150
# 242/242 [==============================] - 0s 139us/sample - loss: 0.2922 - acc: 0.8636 - val_loss: 0.8616 - val_acc: 0.6557
# Epoch 143/150
# 242/242 [==============================] - 0s 145us/sample - loss: 0.2727 - acc: 0.8926 - val_loss: 0.8957 - val_acc: 0.6393
# Epoch 144/150
# 242/242 [==============================] - 0s 150us/sample - loss: 0.2758 - acc: 0.8967 - val_loss: 0.7571 - val_acc: 0.6557
# Epoch 145/150
# 242/242 [==============================] - 0s 138us/sample - loss: 0.2892 - acc: 0.8926 - val_loss: 1.0095 - val_acc: 0.6066
# Epoch 146/150
# 242/242 [==============================] - 0s 149us/sample - loss: 0.2716 - acc: 0.9050 - val_loss: 0.6745 - val_acc: 0.6721
# Epoch 147/150
# 242/242 [==============================] - 0s 140us/sample - loss: 0.2721 - acc: 0.8967 - val_loss: 0.7592 - val_acc: 0.6721
# Epoch 148/150
# 242/242 [==============================] - 0s 135us/sample - loss: 0.2830 - acc: 0.8926 - val_loss: 0.6814 - val_acc: 0.6885
# Epoch 149/150
# 242/242 [==============================] - 0s 169us/sample - loss: 0.2764 - acc: 0.9008 - val_loss: 1.0886 - val_acc: 0.5738
# Epoch 150/150
# 242/242 [==============================] - 0s 149us/sample - loss: 0.2904 - acc: 0.8802 - val_loss: 1.1292 - val_acc: 0.5902

# %% [markdown]
# #Plot Training History
# [Model Visualization](https://keras.io/visualization/#model-visualization)
#
# Plot training & validation accuracy values

# %%
from keras.utils import plot_model
plot_model
# Out:
# <function keras.utils.vis_utils.plot_model>

# %% [markdown]
# #Evaluate Model
# [Keras Evaluate Model](https://keras.io/models/model/#evaluate)

# %%
model.evaluate
# Out:
# <bound method Model.evaluate of <tensorflow.python.keras.engine.sequential.Sequential object at 0x7fd9934bdda0>>

# %% [markdown]
# #Predict
# [Keras Predic](https://keras.io/models/model/#predict)
#
# Machine learnt how to diagnose diabetes, now let machine take the doctor's position

# %%
model.predict
# Out:
# <bound method Model.predict of <tensorflow.python.keras.engine.sequential.Sequential object at 0x7fd9934bdda0>>

# %% [markdown]
# #Project Reference
# [Kaggle -> UCI](https://www.kaggle.com/nozziel/heart-disease-uci-explainable-model-shap/notebook)
